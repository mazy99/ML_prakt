# %%
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/my_file.txt'

with open(file_path,'w') as f:
  f.write("Этот файл создан в Google Colab.\n")
  f.write("Быть или не быть вот в чем вопрос?")
print("Файл успешно сохранен в Google Drive.")

with open(file_path,'r') as f:
  content = f.read()
  print(f"Содержимое файла:\n {content}")

friends = [['Новиков Е.А',19,'CS'],
           ['Брякин А.А', 20,'footboll'],
           ['Собчак А.Е', 21,'dota']]
csv_path = "/content/drive/MyDrive/friends.csv"
with open(csv_path,'w') as f:
  for friend in friends:
      f.write(",".join(map(str, friend)) + "\n")

print('Файл сохранен')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Файл успешно сохранен в Google Drive.
# Содержимое файла:
#  Этот файл создан в Google Colab.
# Быть или не быть вот в чем вопрос?
# Файл сохранен
